# %%
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\.conda\envs\virenv1\lib\tempfile.py in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     257         try:
# --> 258             fd = _os.open(file, flags, 0o600)
#     259         except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\tmp6i9vu8rr'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2788\1539075493.py in <module>
# ----> 1 from ultralytics import YOLO
#       2 import cv2
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ~\.conda\envs\virenv1\lib\site-packages\ultralytics\__init__.py in <module>
#       3 __version__ = '8.0.55'
#       4
# ----> 5 from ultralytics.yolo.engine.model import YOLO
# ...

# %%
model_dir = "C:/Users/DELL Inspiron/Downloads/weights-20230321T054803Z-001/weights/best.pt"
model = YOLO(model_dir)

# %%
vid_dir = "C:/Users/DELL Inspiron/Desktop/Computer Vision Projects/Thesis_data/IMG_2573.MOV"
